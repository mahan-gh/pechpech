# %%
import whisper
import numpy as np
import torch
import soundfile as sf
from io import BytesIO

from pydub import AudioSegment

# %%
model = whisper.load_model('small')

# %%
with open("song.mp3", 'rb') as f:
    data = f.read()

# %%
with open('temp.mp3', 'wb') as f:
    f.write(data)

# %%
result = model.transcribe(buffer)
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 result = model.transcribe(buffer)
#
# File ~/.local/lib/python3.11/site-packages/whisper/transcribe.py:122, in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, **decode_options)
#     119     decode_options["fp16"] = False
#     121 # Pad 30-seconds of silence to the input audio, for slicing
# --> 122 mel = log_mel_spectrogram(audio, model.dims.n_mels, padding=N_SAMPLES)
#     123 content_frames = mel.shape[-1] - N_FRAMES
#     125 if decode_options.get("language", None) is None:
#
# File ~/.local/lib/python3.11/site-packages/whisper/audio.py:141, in log_mel_spectrogram(audio, n_mels, padding, device)
#     139     if isinstance(audio, str):
#     140         audio = load_audio(audio)
# --> 141     audio = torch.from_numpy(audio)
#     143 if device is not None:
#     144     audio = audio.to(device)
#
# TypeError: expected np.ndarray (got _io.BytesIO)

# %%
result = model.transcribe('song.mp3')
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
result
# Out:
# {'text': ' Are you ready kids? I can hear you! Oh, who lives in a pineapple under the sea Of torment and yellow and poruses heave If not a good nonsense be something you wish Then drop on the deck and plump like a fish Ready? SpongeBob SquarePants Those are fucking nuts',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 4.0,
#    'text': ' Are you ready kids?',
#    'tokens': [50364, 2014, 291, 1919, 2301, 30, 50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.44876670837402344,
#    'compression_ratio': 1.2734375,
#    'no_speech_prob': 0.48922598361968994},
#   {'id': 1,
#    'seek': 0,
#    'start': 4.0,
#    'end': 8.0,
#    'text': ' I can hear you!',
#    'tokens': [50564, 286, 393, 1568, 291, 0, 50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.44876670837402344,
#    'compression_ratio': 1.2734375,
#    'no_speech_prob': 0.48922598361968994},
#   {'id': 2,
#    'seek': 0,
#    'start': 8.0,
#    'end': 15.0,
#    'text': ' Oh, who lives in a pineapple under the sea',
#    'tokens': [50764,
#     876,
#     11,
#     567,
#     2909,
#     294,
#     257,
#     25740,
#     833,
#     264,
#     4158,
#     51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.44876670837402344,
#    'compression_ratio': 1.2734375,
#    'no_speech_prob': 0.48922598361968994},
#   {'id': 3,
#    'seek': 0,
#    'start': 15.0,
#    'end': 20.0,
#    'text': ' Of torment and yellow and poruses heave',
#    'tokens': [51114, 2720, 36662, 293, 5566, 293, 1515, 8355, 415, 946, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.44876670837402344,
#    'compression_ratio': 1.2734375,
#    'no_speech_prob': 0.48922598361968994},
#   {'id': 4,
#    'seek': 0,
#    'start': 20.0,
#    'end': 24.0,
#    'text': ' If not a good nonsense be something you wish',
#    'tokens': [51364, 759, 406, 257, 665, 14925, 312, 746, 291, 3172, 51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.44876670837402344,
#    'compression_ratio': 1.2734375,
#    'no_speech_prob': 0.48922598361968994},
#   {'id': 5,
#    'seek': 2400,
#    'start': 25.0,
#    'end': 29.0,
#    'text': ' Then drop on the deck and plump like a fish',
#    'tokens': [50414,
#     1396,
#     3270,
#     322,
#     264,
#     9341,
#     293,
#     499,
#     1420,
#     411,
#     257,
#     3506,
#     50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.3512972247216009,
#    'compression_ratio': 1.0674157303370786,
#    'no_speech_prob': 0.0783671885728836},
#   {'id': 6,
#    'seek': 2400,
#    'start': 29.0,
#    'end': 30.0,
#    'text': ' Ready?',
#    'tokens': [50614, 9944, 30, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.3512972247216009,
#    'compression_ratio': 1.0674157303370786,
#    'no_speech_prob': 0.0783671885728836},
#   {'id': 7,
#    'seek': 2400,
#    'start': 30.0,
#    'end': 40.0,
#    'text': ' SpongeBob SquarePants',
#    'tokens': [50664, 43742, 22547, 16463, 47, 1719, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.3512972247216009,
#    'compression_ratio': 1.0674157303370786,
#    'no_speech_prob': 0.0783671885728836},
#   {'id': 8,
#    'seek': 2400,
#    'start': 40.0,
#    'end': 42.0,
#    'text': ' Those are fucking nuts',
#    'tokens': [51164, 3950, 366, 5546, 10483, 51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.3512972247216009,
#    'compression_ratio': 1.0674157303370786,
#    'no_speech_prob': 0.0783671885728836}],
#  'language': 'en'}

# %%
result["segments"]
# Out:
# [{'id': 0,
#   'seek': 0,
#   'start': 0.0,
#   'end': 4.0,
#   'text': ' Are you ready kids?',
#   'tokens': [50364, 2014, 291, 1919, 2301, 30, 50564],
#   'temperature': 0.0,
#   'avg_logprob': -0.5231703622000557,
#   'compression_ratio': 1.4545454545454546,
#   'no_speech_prob': 0.4342014789581299},
#  {'id': 1,
#   'seek': 0,
#   'start': 4.0,
#   'end': 8.0,
#   'text': " I can't hear you!",
#   'tokens': [50564, 286, 393, 380, 1568, 291, 0, 50764],
#   'temperature': 0.0,
#   'avg_logprob': -0.5231703622000557,
#   'compression_ratio': 1.4545454545454546,
#   'no_speech_prob': 0.4342014789581299},
#  {'id': 2,
#   'seek': 0,
#   'start': 8.0,
#   'end': 16.0,
#   'text': ' Who lives in a pineapple under the sea?',
#   'tokens': [50764, 2102, 2909, 294, 257, 25740, 833, 264, 4158, 30, 51164],
#   'temperature': 0.0,
#   'avg_logprob': -0.5231703622000557,
#   'compression_ratio': 1.4545454545454546,
#   'no_speech_prob': 0.4342014789581299},
#  {'id': 3,
#   'seek': 0,
#   'start': 16.0,
#   'end': 20.0,
#   'text': ' A torrentine yellow and porous as he!',
#   'tokens': [51164,
#    316,
#    3930,
#    1753,
#    533,
#    5566,
#    293,
#    1515,
#    563,
#    382,
#    415,
#    0,
#    51364],
#   'temperature': 0.0,
#   'avg_logprob': -0.5231703622000557,
#   'compression_ratio': 1.4545454545454546,
#   'no_speech_prob': 0.4342014789581299},
#  {'id': 4,
#   'seek': 0,
#   'start': 20.0,
#   'end': 22.0,
#   'text': ' A pineapple, say that!',
#   'tokens': [51364, 316, 25740, 11, 584, 300, 0, 51464],
#   'temperature': 0.0,
#   'avg_logprob': -0.5231703622000557,
#   'compression_ratio': 1.4545454545454546,
#   'no_speech_prob': 0.4342014789581299},
#  {'id': 5,
#   'seek': 0,
#   'start': 22.0,
#   'end': 24.0,
#   'text': ' If not a cold nonsense, be something you wish!',
#   'tokens': [51464,
#    759,
#    406,
#    257,
#    3554,
#    14925,
#    11,
#    312,
#    746,
#    291,
#    3172,
#    0,
#    51564],
#   'temperature': 0.0,
#   'avg_logprob': -0.5231703622000557,
#   'compression_ratio': 1.4545454545454546,
#   'no_speech_prob': 0.4342014789581299},
#  {'id': 6,
#   'seek': 0,
#   'start': 24.0,
#   'end': 26.0,
#   'text': ' A pineapple, say that!',
#   'tokens': [51564, 316, 25740, 11, 584, 300, 0, 51664],
#   'temperature': 0.0,
#   'avg_logprob': -0.5231703622000557,
#   'compression_ratio': 1.4545454545454546,
#   'no_speech_prob': 0.4342014789581299},
#  {'id': 7,
#   'seek': 2600,
#   'start': 26.0,
#   'end': 28.0,
#   'text': ' Come on from the deck and come like a fish!',
#   'tokens': [50364,
#    2492,
#    322,
#    490,
#    264,
#    9341,
#    293,
#    808,
#    411,
#    257,
#    3506,
#    0,
#    50464],
#   'temperature': 0.0,
#   'avg_logprob': -0.3153293927510579,
#   'compression_ratio': 1.9222222222222223,
#   'no_speech_prob': 0.0605936162173748},
#  {'id': 8,
#   'seek': 2600,
#   'start': 28.0,
#   'end': 30.0,
#   'text': ' SpongeBob Square!',
#   'tokens': [50464, 43742, 22547, 16463, 0, 50564],
#   'temperature': 0.0,
#   'avg_logprob': -0.3153293927510579,
#   'compression_ratio': 1.9222222222222223,
#   'no_speech_prob': 0.0605936162173748},
#  {'id': 9,
#   'seek': 2600,
#   'start': 30.0,
#   'end': 32.0,
#   'text': ' SpongeBob SquarePads!',
#   'tokens': [50564, 43742, 22547, 16463, 47, 5834, 0, 50664],
#   'temperature': 0.0,
#   'avg_logprob': -0.3153293927510579,
#   'compression_ratio': 1.9222222222222223,
#   'no_speech_prob': 0.0605936162173748},
#  {'id': 10,
#   'seek': 2600,
#   'start': 32.0,
#   'end': 34.0,
#   'text': ' SpongeBob SquarePads!',
#   'tokens': [50664, 43742, 22547, 16463, 47, 5834, 0, 50764],
#   'temperature': 0.0,
#   'avg_logprob': -0.3153293927510579,
#   'compression_ratio': 1.9222222222222223,
#   'no_speech_prob': 0.0605936162173748},
#  {'id': 11,
#   'seek': 2600,
#   'start': 34.0,
#   'end': 36.0,
#   'text': ' SpongeBob SquarePads!',
#   'tokens': [50764, 43742, 22547, 16463, 47, 5834, 0, 50864],
#   'temperature': 0.0,
#   'avg_logprob': -0.3153293927510579,
#   'compression_ratio': 1.9222222222222223,
#   'no_speech_prob': 0.0605936162173748},
#  {'id': 12,
#   'seek': 2600,
#   'start': 36.0,
#   'end': 40.0,
#   'text': ' SpongeBob SquarePads!',
#   'tokens': [50864, 43742, 22547, 16463, 47, 5834, 0, 51064],
#   'temperature': 0.0,
#   'avg_logprob': -0.3153293927510579,
#   'compression_ratio': 1.9222222222222223,
#   'no_speech_prob': 0.0605936162173748},
#  {'id': 13,
#   'seek': 2600,
#   'start': 40.0,
#   'end': 42.0,
#   'text': " Here's a fucking dance!",
#   'tokens': [51064, 1692, 311, 257, 5546, 4489, 0, 51164],
#   'temperature': 0.0,
#   'avg_logprob': -0.3153293927510579,
#   'compression_ratio': 1.9222222222222223,
#   'no_speech_prob': 0.0605936162173748}]

# %%
# base model
from pprint import pprint
pprint(result["text"])
# Out:
# (" Are you ready kids? I can't hear you! Who lives in a pineapple under the "
#  'sea? A torrentine yellow and porous as he! A pineapple, say that! If not a '
#  'cold nonsense, be something you wish! A pineapple, say that! Come on from '
#  'the deck and come like a fish! SpongeBob Square! SpongeBob SquarePads! '
#  "SpongeBob SquarePads! SpongeBob SquarePads! SpongeBob SquarePads! Here's a "
#  'fucking dance!')

# %%
# small model
from pprint import pprint
pprint(result["text"])
# Out:
# (' Are you ready kids? I can hear you! Oh, who lives in a pineapple under the '
#  'sea Of torment and yellow and poruses heave If not a good nonsense be '
#  'something you wish Then drop on the deck and plump like a fish Ready? '
#  'SpongeBob SquarePants Those are fucking nuts')
